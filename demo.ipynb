# %%
from src.utils import load_data
from src.algos import *

# %%
df = load_data('data\TSP_29.xlsx')

# %%
s = SimulatedAnnealing(temp=100, alpha=0.9, n_iter=1000, verbose=False)
s.solve(df)
# Out:
# best distance: 2971
# algorithm: SIMULATED ANNEALING
# n_iter: 1000
# solving time: 0.281 s
# history: [6247, 6055, 5956, 5395, 5213, 5082, 5123, 5123, 4939, 4898, 4803, 4751, 4728, 4723, 4617, 4303, 4296, 4240, 4175, 3937, 3895, 3879, 3879, 3846, 3698, 3698, 3695, 3645, 3518, 3513, 3479, 3448, 3448, 3448, 3447, 3418, 3416, 3416, 3411, 3411, 3367, 3339, 3307, 3261, 3254, 3251, 3174, 3169, 3112, 3100, 3078, 3011, 2988, 2971]

# %%
n = NearestNeighbour(verbose=False)
n.solve(df, 14)
# Out:
# best distance: 2293
# algorithm: NEAREST NEIGHBOUR
# solving time: 0.014 s

# %%
t = TabuSearch(verbose=False, tabu_length=3 , n_iter=30)
t.solve(df)
# Out:
# best distance: 2384
# algorithm: TABU SEARCH
# n_iter: 30
# solving time: 3.200 s
# history: [5659, 5019, 4384, 3966, 3715, 3520, 3335, 3215, 3108, 2964, 2887, 2832, 2785, 2649, 2593, 2547, 2521, 2496, 2486, 2417, 2413, 2407, 2398, 2393, 2385, 2375, 2376, 2378, 2380, 2385, 2384]

# %%
h = HillClimber(verbose=False, n_iter=30)
h.solve(df)
# Out:
# best distance: 2404
# algorithm: HILL CLIMBER
# n_iter: 30
# solving time: 1.789 s
# history: [5709, 5078, 4555, 4085, 3689, 3323, 3148, 3006, 2893, 2788, 2699, 2618, 2544, 2473, 2433, 2412, 2404]

# %%
from matplotlib import pyplot as plt
plt.plot(t.history, label=t.NAME)
plt.plot(h.history, label=h.NAME)
plt.plot(s.history, label=s.NAME)
plt.legend()
